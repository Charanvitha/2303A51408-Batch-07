# %% [markdown]
# <a href="https://colab.research.google.com/github/Charanvitha/2303A51408-Batch-07/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2303A51408    batch-07
# Lab-08

# %% [markdown]
# Create a Bar Chart Using Matplotlib.
# • Population of Countries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("population.csv")

# %%
# Sort by population and select top 5
top5 = df.sort_values(by="Population", ascending=False).head(5)

# %%
# Plot bar chart
plt.figure(figsize=(8,6))
plt.bar(top5["Country"], top5["Population"], color="skyblue", edgecolor="black")
# Out:
# <BarContainer object of 5 artists>

# %%
# Title and labels
plt.title("Population of Top 5 Countries", fontsize=14, weight="bold")
plt.xlabel("Country", fontsize=12)
plt.ylabel("Population (in Billions)", fontsize=12)
# Out:
# Text(0, 0.5, 'Population (in Billions)')

# %%
# Format y-axis to billions
plt.gca().set_yticks([0, 500_000_000, 1_000_000_000, 1_500_000_000])
plt.gca().set_yticklabels(["0", "0.5B", "1B", "1.5B"])
# Out:
# [Text(0, 0, '0'),
#  Text(0, 500000000, '0.5B'),
#  Text(0, 1000000000, '1B'),
#  Text(0, 1500000000, '1.5B')]

# %%
# Show gridlines
plt.grid(axis="y", linestyle="--", alpha=0.6)

# %%
# Display chart
plt.show()

# %% [markdown]
# Create a Bar Chart Using Matplotlib.
# • Number of Movies Produced by Genres

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("movies_genre.csv")

# %%
# Plot bar chart
plt.figure(figsize=(10,6))
plt.bar(df["Genre"], df["Movie_Count"], color="teal", edgecolor="black")
# Out:
# <BarContainer object of 11 artists>

# %%
# Title and labels
plt.title("Number of Movies Produced by Genre", fontsize=14, weight="bold")
plt.xlabel("Genre", fontsize=12)
plt.ylabel("Number of Movies", fontsize=12)
# Out:
# Text(0, 0.5, 'Number of Movies')

# %%
# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha="right")
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
# Add gridlines
plt.grid(axis="y", linestyle="--", alpha=0.6)

# %%
# Display chart
plt.tight_layout()
plt.show()
